# %% [markdown]
# # Tarefa 01
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os monitores
# - Divirta-se :)

# %% [markdown]
# #### 1. Baixando dados de ativos
#     1. Baixe os dados de três ativos da sua escolha do Yahoo Finance, correspondente a um período de pelo menos 2 anos até a data mais recente.
#     2. Salve esses dados para que você possa utilizá-los na próxima tarefa.

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta

ativos = ['AAPL', 'MSFT', 'GOOGL'] 

data_final = datetime.today()
data_inicial = data_final - timedelta(days=2*365)

dados_ativos = {}

for ativo in ativos:
    df = yf.download(ativo, start=data_inicial.strftime('%Y-%m-%d'), end=data_final.strftime('%Y-%m-%d'))
    dados_ativos[ativo] = df

    df.to_csv(f'{ativo}_2anos.csv')
    print(f'Dados do ativo {ativo} salvos em {ativo}_2anos.csv')
# Out:
# C:\Users\shinoki\AppData\Local\Temp\ipykernel_7568\4273932816.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ativo, start=data_inicial.strftime('%Y-%m-%d'), end=data_final.strftime('%Y-%m-%d'))
# [*********************100%***********************]  1 of 1 completed
# Dados do ativo AAPL salvos em AAPL_2anos.csv
# C:\Users\shinoki\AppData\Local\Temp\ipykernel_7568\4273932816.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ativo, start=data_inicial.strftime('%Y-%m-%d'), end=data_final.strftime('%Y-%m-%d'))
# [*********************100%***********************]  1 of 1 completed
# C:\Users\shinoki\AppData\Local\Temp\ipykernel_7568\4273932816.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ativo, start=data_inicial.strftime('%Y-%m-%d'), end=data_final.strftime('%Y-%m-%d'))
# Dados do ativo MSFT salvos em MSFT_2anos.csv
# [*********************100%***********************]  1 of 1 completed
# Dados do ativo GOOGL salvos em GOOGL_2anos.csv

# %% [markdown]
# #### 2. Observando a volatilidade dentro do dia
# 1. Calcule a amplitude de variação do valor do ativo dentro do dia. Essa amplitude você pode calcular com um comando simples de adicionar uma coluna no Pandas: (valor máximo - valor mínimo).
# 2. Monte um gráfico de linha mostrando a variação dessa amplitude ao longo do período coletado, por ativo.
# 3. Veja se consegue identificar que ativo apresentou maior volatilidade.

# %%
import matplotlib.pyplot as plt

ativos = ['AAPL', 'MSFT', 'GOOGL']

data_final = datetime.today()
data_inicial = data_final - timedelta(days=2*365)

for ativo in ativos:
    df = yf.download(ativo, start=data_inicial.strftime('%Y-%m-%d'), end=data_final.strftime('%Y-%m-%d'))

    df['Amplitude'] = df['High'] - df['Low']

    plt.figure(figsize=(14, 5))
    plt.plot(df.index, df['Amplitude'], label=f'Amplitude diária - {ativo}')
    plt.title(f'Variação Diária de Amplitude - {ativo}')
    plt.xlabel('Data')
    plt.ylabel('Amplitude (USD)')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

    df.to_csv(f'{ativo}_com_amplitude.csv')
# Out:
# C:\Users\shinoki\AppData\Local\Temp\ipykernel_7568\1760227985.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ativo, start=data_inicial.strftime('%Y-%m-%d'), end=data_final.strftime('%Y-%m-%d'))
# [*********************100%***********************]  1 of 1 completed
# C:\Users\shinoki\AppData\Local\Temp\ipykernel_7568\1760227985.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ativo, start=data_inicial.strftime('%Y-%m-%d'), end=data_final.strftime('%Y-%m-%d'))
# [*********************100%***********************]  1 of 1 completed
# C:\Users\shinoki\AppData\Local\Temp\ipykernel_7568\1760227985.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ativo, start=data_inicial.strftime('%Y-%m-%d'), end=data_final.strftime('%Y-%m-%d'))
# [*********************100%***********************]  1 of 1 completed

# %%
#Acredito que o que mais apresentou volatilidade foi o ativo do Google
